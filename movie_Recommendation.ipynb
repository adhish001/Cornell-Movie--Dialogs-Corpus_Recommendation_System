# %%
# !pip install convokit
from convokit import Corpus, download
corpus = Corpus(filename=download("movie-corpus"))
# Out:
# Requirement already satisfied: convokit in /usr/local/lib/python3.10/dist-packages (3.0.0)
# Requirement already satisfied: matplotlib>=3.0.0 in /usr/local/lib/python3.10/dist-packages (from convokit) (3.7.1)
# Requirement already satisfied: pandas>=0.23.4 in /usr/local/lib/python3.10/dist-packages (from convokit) (1.5.3)
# Requirement already satisfied: msgpack-numpy>=0.4.3.2 in /usr/local/lib/python3.10/dist-packages (from convokit) (0.4.8)
# Requirement already satisfied: spacy>=2.3.5 in /usr/local/lib/python3.10/dist-packages (from convokit) (3.6.1)
# Requirement already satisfied: scipy>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from convokit) (1.11.2)
# Requirement already satisfied: scikit-learn>=0.20.0 in /usr/local/lib/python3.10/dist-packages (from convokit) (1.2.2)
# Requirement already satisfied: nltk>=3.4 in /usr/local/lib/python3.10/dist-packages (from convokit) (3.8.1)
# Requirement already satisfied: dill>=0.2.9 in /usr/local/lib/python3.10/dist-packages (from convokit) (0.3.7)
# Requirement already satisfied: joblib>=0.13.2 in /usr/local/lib/python3.10/dist-packages (from convokit) (1.3.2)
# Requirement already satisfied: clean-text>=0.6.0 in /usr/local/lib/python3.10/dist-packages (from convokit) (0.6.0)
# Requirement already satisfied: unidecode>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from convokit) (1.3.7)
# Requirement already satisfied: tqdm>=4.64.0 in /usr/local/lib/python3.10/dist-packages (from convokit) (4.66.1)
# Requirement already satisfied: pymongo>=4.0 in /usr/local/lib/python3.10/dist-packages (from convokit) (4.5.0)
# Requirement already satisfied: pyyaml>=5.4.1 in /usr/local/lib/python3.10/dist-packages (from convokit) (6.0.1)
# Requirement already satisfied: dnspython>=1.16.0 in /usr/local/lib/python3.10/dist-packages (from convokit) (2.4.2)
# Requirement already satisfied: emoji<2.0.0,>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from clean-text>=0.6.0->convokit) (1.7.0)
# Requirement already satisfied: ftfy<7.0,>=6.0 in /usr/local/lib/python3.10/dist-packages (from clean-text>=0.6.0->convokit) (6.1.1)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.0.0->convokit) (1.1.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.0.0->convokit) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.0.0->convokit) (4.42.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.0.0->convokit) (1.4.5)
# Requirement already satisfied: numpy>=1.20 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.0.0->convokit) (1.23.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.0.0->convokit) (23.1)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.0.0->convokit) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.0.0->convokit) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.0.0->convokit) (2.8.2)
# Requirement already satisfied: msgpack>=0.5.2 in /usr/local/lib/python3.10/dist-packages (from msgpack-numpy>=0.4.3.2->convokit) (1.0.5)
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from nltk>=3.4->convokit) (8.1.7)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.10/dist-packages (from nltk>=3.4->convokit) (2023.6.3)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.23.4->convokit) (2023.3.post1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=0.20.0->convokit) (3.2.0)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in /usr/local/lib/python3.10/dist-packages (from spacy>=2.3.5->convokit) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from spacy>=2.3.5->convokit) (1.0.4)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.10/dist-packages (from spacy>=2.3.5->convokit) (1.0.9)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.10/dist-packages (from spacy>=2.3.5->convokit) (2.0.7)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.10/dist-packages (from spacy>=2.3.5->convokit) (3.0.8)
# Requirement already satisfied: thinc<8.2.0,>=8.1.8 in /usr/local/lib/python3.10/dist-packages (from spacy>=2.3.5->convokit) (8.1.12)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in /usr/local/lib/python3.10/dist-packages (from spacy>=2.3.5->convokit) (1.1.2)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /usr/local/lib/python3.10/dist-packages (from spacy>=2.3.5->convokit) (2.4.7)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /usr/local/lib/python3.10/dist-packages (from spacy>=2.3.5->convokit) (2.0.9)
# Requirement already satisfied: typer<0.10.0,>=0.3.0 in /usr/local/lib/python3.10/dist-packages (from spacy>=2.3.5->convokit) (0.9.0)
# Requirement already satisfied: pathy>=0.10.0 in /usr/local/lib/python3.10/dist-packages (from spacy>=2.3.5->convokit) (0.10.2)
# Requirement already satisfied: smart-open<7.0.0,>=5.2.1 in /usr/local/lib/python3.10/dist-packages (from spacy>=2.3.5->convokit) (6.4.0)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from spacy>=2.3.5->convokit) (2.31.0)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in /usr/local/lib/python3.10/dist-packages (from spacy>=2.3.5->convokit) (1.10.12)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from spacy>=2.3.5->convokit) (3.1.2)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from spacy>=2.3.5->convokit) (67.7.2)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /usr/local/lib/python3.10/dist-packages (from spacy>=2.3.5->convokit) (3.3.0)
# Requirement already satisfied: wcwidth>=0.2.5 in /usr/local/lib/python3.10/dist-packages (from ftfy<7.0,>=6.0->clean-text>=0.6.0->convokit) (0.2.6)
# Requirement already satisfied: typing-extensions>=4.2.0 in /usr/local/lib/python3.10/dist-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy>=2.3.5->convokit) (4.5.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib>=3.0.0->convokit) (1.16.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy>=2.3.5->convokit) (3.2.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy>=2.3.5->convokit) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy>=2.3.5->convokit) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy>=2.3.5->convokit) (2023.7.22)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in /usr/local/lib/python3.10/dist-packages (from thinc<8.2.0,>=8.1.8->spacy>=2.3.5->convokit) (0.7.10)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /usr/local/lib/python3.10/dist-packages (from thinc<8.2.0,>=8.1.8->spacy>=2.3.5->convokit) (0.1.2)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->spacy>=2.3.5->convokit) (2.1.3)
# Downloading movie-corpus to /root/.convokit/downloads/movie-corpus
# Downloading movie-corpus from http://zissou.infosci.cornell.edu/convokit/datasets/movie-corpus/movie-corpus.zip (40.9MB)... Done

# %%
corpus.print_summary_stats()
# Out:
# Number of Speakers: 9035
# Number of Utterances: 304713
# Number of Conversations: 83097

# %%
# !pip install scikit-surprise
# Out:
# Requirement already satisfied: scikit-surprise in /usr/local/lib/python3.10/dist-packages (1.1.3)
# Requirement already satisfied: joblib>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-surprise) (1.3.2)
# Requirement already satisfied: numpy>=1.17.3 in /usr/local/lib/python3.10/dist-packages (from scikit-surprise) (1.23.5)
# Requirement already satisfied: scipy>=1.3.2 in /usr/local/lib/python3.10/dist-packages (from scikit-surprise) (1.11.2)

# %%
import pandas as pd
from surprise import Dataset,Reader,SVD
from surprise.model_selection import train_test_split
from surprise import accuracy
import matplotlib.pyplot as plt

# %%
#Basic statistics
print("Number of conversations:", len(corpus.conversations))
print("Number of users:", len(corpus.speakers))
print("Number of utterances:", len(corpus.utterances))
# Out:
# Number of conversations: 83097
# Number of users: 9035
# Number of utterances: 304713

# %%
#Information about conversations
for convo in corpus.iter_conversations():
    print("Conversation ID:", convo.get_id())
    print("Metadata:", convo.meta)
    print("Number of utterances in conversation:", len(convo.get_utterance_ids()))
    print()
# Out:
# Streaming output truncated to the last 5000 lines.
# Number of utterances in conversation: 2
#
# Conversation ID: L355817
# Metadata: ConvoKitMeta({'movie_idx': 'm123', 'movie_name': 'lost highway', 'release_year': '1997', 'rating': '7.60', 'votes': '42998', 'genre': "['drama', 'horror', 'mystery', 'thriller']"})
# Number of utterances in conversation: 8
#
# Conversation ID: L355856
# Metadata: ConvoKitMeta({'movie_idx': 'm123', 'movie_name': 'lost highway', 'release_year': '1997', 'rating': '7.60', 'votes': '42998', 'genre': "['drama', 'horror', 'mystery', 'thriller']"})
# Number of utterances in conversation: 5
#
# Conversation ID: L355851
# Metadata: ConvoKitMeta({'movie_idx': 'm123', 'movie_name': 'lost highway', 'release_year': '1997', 'rating': '7.60', 'votes': '42998', 'genre': "['drama', 'horror', 'mystery', 'thriller']"})
# Number of utterances in conversation: 4
#
# Conversation ID: L355847
# Metadata: ConvoKitMeta({'movie_idx': 'm123', 'movie_name': 'lost highway', 'release_year': '1997', 'rating': '7.60', 'votes': '42998', 'genre': "['drama', 'horror', 'mystery', 'thriller']"})
# Number of utterances in conversation: 3
#
# Conversation ID: L355836
# Metadata: ConvoKitMeta({'movie_idx': 'm123', 'movie_name': 'lost highway', 'release_year': '1997', 'rating': '7.60', 'votes': '42998', 'genre': "['drama', 'horror', 'mystery', 'thriller']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L355814
# Metadata: ConvoKitMeta({'movie_idx': 'm123', 'movie_name': 'lost highway', 'release_year': '1997', 'rating': '7.60', 'votes': '42998', 'genre': "['drama', 'horror', 'mystery', 'thriller']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L355807
# Metadata: ConvoKitMeta({'movie_idx': 'm123', 'movie_name': 'lost highway', 'release_year': '1997', 'rating': '7.60', 'votes': '42998', 'genre': "['drama', 'horror', 'mystery', 'thriller']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L355798
# Metadata: ConvoKitMeta({'movie_idx': 'm123', 'movie_name': 'lost highway', 'release_year': '1997', 'rating': '7.60', 'votes': '42998', 'genre': "['drama', 'horror', 'mystery', 'thriller']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L355792
# Metadata: ConvoKitMeta({'movie_idx': 'm123', 'movie_name': 'lost highway', 'release_year': '1997', 'rating': '7.60', 'votes': '42998', 'genre': "['drama', 'horror', 'mystery', 'thriller']"})
# Number of utterances in conversation: 3
#
# Conversation ID: L355790
# Metadata: ConvoKitMeta({'movie_idx': 'm123', 'movie_name': 'lost highway', 'release_year': '1997', 'rating': '7.60', 'votes': '42998', 'genre': "['drama', 'horror', 'mystery', 'thriller']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L355786
# Metadata: ConvoKitMeta({'movie_idx': 'm123', 'movie_name': 'lost highway', 'release_year': '1997', 'rating': '7.60', 'votes': '42998', 'genre': "['drama', 'horror', 'mystery', 'thriller']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L355747
# Metadata: ConvoKitMeta({'movie_idx': 'm123', 'movie_name': 'lost highway', 'release_year': '1997', 'rating': '7.60', 'votes': '42998', 'genre': "['drama', 'horror', 'mystery', 'thriller']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L355743
# Metadata: ConvoKitMeta({'movie_idx': 'm123', 'movie_name': 'lost highway', 'release_year': '1997', 'rating': '7.60', 'votes': '42998', 'genre': "['drama', 'horror', 'mystery', 'thriller']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L355739
# Metadata: ConvoKitMeta({'movie_idx': 'm123', 'movie_name': 'lost highway', 'release_year': '1997', 'rating': '7.60', 'votes': '42998', 'genre': "['drama', 'horror', 'mystery', 'thriller']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L355737
# Metadata: ConvoKitMeta({'movie_idx': 'm123', 'movie_name': 'lost highway', 'release_year': '1997', 'rating': '7.60', 'votes': '42998', 'genre': "['drama', 'horror', 'mystery', 'thriller']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L355734
# Metadata: ConvoKitMeta({'movie_idx': 'm123', 'movie_name': 'lost highway', 'release_year': '1997', 'rating': '7.60', 'votes': '42998', 'genre': "['drama', 'horror', 'mystery', 'thriller']"})
# Number of utterances in conversation: 3
#
# Conversation ID: L355728
# Metadata: ConvoKitMeta({'movie_idx': 'm123', 'movie_name': 'lost highway', 'release_year': '1997', 'rating': '7.60', 'votes': '42998', 'genre': "['drama', 'horror', 'mystery', 'thriller']"})
# Number of utterances in conversation: 3
#
# Conversation ID: L355716
# Metadata: ConvoKitMeta({'movie_idx': 'm123', 'movie_name': 'lost highway', 'release_year': '1997', 'rating': '7.60', 'votes': '42998', 'genre': "['drama', 'horror', 'mystery', 'thriller']"})
# Number of utterances in conversation: 11
#
# Conversation ID: L355714
# Metadata: ConvoKitMeta({'movie_idx': 'm123', 'movie_name': 'lost highway', 'release_year': '1997', 'rating': '7.60', 'votes': '42998', 'genre': "['drama', 'horror', 'mystery', 'thriller']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L355706
# Metadata: ConvoKitMeta({'movie_idx': 'm123', 'movie_name': 'lost highway', 'release_year': '1997', 'rating': '7.60', 'votes': '42998', 'genre': "['drama', 'horror', 'mystery', 'thriller']"})
# Number of utterances in conversation: 6
#
# Conversation ID: L355702
# Metadata: ConvoKitMeta({'movie_idx': 'm123', 'movie_name': 'lost highway', 'release_year': '1997', 'rating': '7.60', 'votes': '42998', 'genre': "['drama', 'horror', 'mystery', 'thriller']"})
# Number of utterances in conversation: 4
#
# Conversation ID: L355698
# Metadata: ConvoKitMeta({'movie_idx': 'm123', 'movie_name': 'lost highway', 'release_year': '1997', 'rating': '7.60', 'votes': '42998', 'genre': "['drama', 'horror', 'mystery', 'thriller']"})
# Number of utterances in conversation: 3
#
# Conversation ID: L355888
# Metadata: ConvoKitMeta({'movie_idx': 'm123', 'movie_name': 'lost highway', 'release_year': '1997', 'rating': '7.60', 'votes': '42998', 'genre': "['drama', 'horror', 'mystery', 'thriller']"})
# Number of utterances in conversation: 4
#
# Conversation ID: L355883
# Metadata: ConvoKitMeta({'movie_idx': 'm123', 'movie_name': 'lost highway', 'release_year': '1997', 'rating': '7.60', 'votes': '42998', 'genre': "['drama', 'horror', 'mystery', 'thriller']"})
# Number of utterances in conversation: 5
#
# Conversation ID: L356361
# Metadata: ConvoKitMeta({'movie_idx': 'm123', 'movie_name': 'lost highway', 'release_year': '1997', 'rating': '7.60', 'votes': '42998', 'genre': "['drama', 'horror', 'mystery', 'thriller']"})
# Number of utterances in conversation: 3
#
# Conversation ID: L356355
# Metadata: ConvoKitMeta({'movie_idx': 'm123', 'movie_name': 'lost highway', 'release_year': '1997', 'rating': '7.60', 'votes': '42998', 'genre': "['drama', 'horror', 'mystery', 'thriller']"})
# Number of utterances in conversation: 6
#
# Conversation ID: L356351
# Metadata: ConvoKitMeta({'movie_idx': 'm123', 'movie_name': 'lost highway', 'release_year': '1997', 'rating': '7.60', 'votes': '42998', 'genre': "['drama', 'horror', 'mystery', 'thriller']"})
# Number of utterances in conversation: 4
#
# Conversation ID: L356261
# Metadata: ConvoKitMeta({'movie_idx': 'm123', 'movie_name': 'lost highway', 'release_year': '1997', 'rating': '7.60', 'votes': '42998', 'genre': "['drama', 'horror', 'mystery', 'thriller']"})
# Number of utterances in conversation: 3
#
# Conversation ID: L356258
# Metadata: ConvoKitMeta({'movie_idx': 'm123', 'movie_name': 'lost highway', 'release_year': '1997', 'rating': '7.60', 'votes': '42998', 'genre': "['drama', 'horror', 'mystery', 'thriller']"})
# Number of utterances in conversation: 3
#
# Conversation ID: L356165
# Metadata: ConvoKitMeta({'movie_idx': 'm123', 'movie_name': 'lost highway', 'release_year': '1997', 'rating': '7.60', 'votes': '42998', 'genre': "['drama', 'horror', 'mystery', 'thriller']"})
# Number of utterances in conversation: 5
#
# Conversation ID: L356158
# Metadata: ConvoKitMeta({'movie_idx': 'm123', 'movie_name': 'lost highway', 'release_year': '1997', 'rating': '7.60', 'votes': '42998', 'genre': "['drama', 'horror', 'mystery', 'thriller']"})
# Number of utterances in conversation: 3
#
# Conversation ID: L356154
# Metadata: ConvoKitMeta({'movie_idx': 'm123', 'movie_name': 'lost highway', 'release_year': '1997', 'rating': '7.60', 'votes': '42998', 'genre': "['drama', 'horror', 'mystery', 'thriller']"})
# Number of utterances in conversation: 4
#
# Conversation ID: L356152
# Metadata: ConvoKitMeta({'movie_idx': 'm123', 'movie_name': 'lost highway', 'release_year': '1997', 'rating': '7.60', 'votes': '42998', 'genre': "['drama', 'horror', 'mystery', 'thriller']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L356144
# Metadata: ConvoKitMeta({'movie_idx': 'm123', 'movie_name': 'lost highway', 'release_year': '1997', 'rating': '7.60', 'votes': '42998', 'genre': "['drama', 'horror', 'mystery', 'thriller']"})
# Number of utterances in conversation: 7
#
# Conversation ID: L356129
# Metadata: ConvoKitMeta({'movie_idx': 'm123', 'movie_name': 'lost highway', 'release_year': '1997', 'rating': '7.60', 'votes': '42998', 'genre': "['drama', 'horror', 'mystery', 'thriller']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L356127
# Metadata: ConvoKitMeta({'movie_idx': 'm123', 'movie_name': 'lost highway', 'release_year': '1997', 'rating': '7.60', 'votes': '42998', 'genre': "['drama', 'horror', 'mystery', 'thriller']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L356115
# Metadata: ConvoKitMeta({'movie_idx': 'm123', 'movie_name': 'lost highway', 'release_year': '1997', 'rating': '7.60', 'votes': '42998', 'genre': "['drama', 'horror', 'mystery', 'thriller']"})
# Number of utterances in conversation: 9
#
# Conversation ID: L356371
# Metadata: ConvoKitMeta({'movie_idx': 'm123', 'movie_name': 'lost highway', 'release_year': '1997', 'rating': '7.60', 'votes': '42998', 'genre': "['drama', 'horror', 'mystery', 'thriller']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L356365
# Metadata: ConvoKitMeta({'movie_idx': 'm123', 'movie_name': 'lost highway', 'release_year': '1997', 'rating': '7.60', 'votes': '42998', 'genre': "['drama', 'horror', 'mystery', 'thriller']"})
# Number of utterances in conversation: 5
#
# Conversation ID: L356340
# Metadata: ConvoKitMeta({'movie_idx': 'm123', 'movie_name': 'lost highway', 'release_year': '1997', 'rating': '7.60', 'votes': '42998', 'genre': "['drama', 'horror', 'mystery', 'thriller']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L356333
# Metadata: ConvoKitMeta({'movie_idx': 'm123', 'movie_name': 'lost highway', 'release_year': '1997', 'rating': '7.60', 'votes': '42998', 'genre': "['drama', 'horror', 'mystery', 'thriller']"})
# Number of utterances in conversation: 5
#
# Conversation ID: L356329
# Metadata: ConvoKitMeta({'movie_idx': 'm123', 'movie_name': 'lost highway', 'release_year': '1997', 'rating': '7.60', 'votes': '42998', 'genre': "['drama', 'horror', 'mystery', 'thriller']"})
# Number of utterances in conversation: 4
#
# Conversation ID: L356228
# Metadata: ConvoKitMeta({'movie_idx': 'm123', 'movie_name': 'lost highway', 'release_year': '1997', 'rating': '7.60', 'votes': '42998', 'genre': "['drama', 'horror', 'mystery', 'thriller']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L356224
# Metadata: ConvoKitMeta({'movie_idx': 'm123', 'movie_name': 'lost highway', 'release_year': '1997', 'rating': '7.60', 'votes': '42998', 'genre': "['drama', 'horror', 'mystery', 'thriller']"})
# Number of utterances in conversation: 4
#
# Conversation ID: L356175
# Metadata: ConvoKitMeta({'movie_idx': 'm123', 'movie_name': 'lost highway', 'release_year': '1997', 'rating': '7.60', 'votes': '42998', 'genre': "['drama', 'horror', 'mystery', 'thriller']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L356170
# Metadata: ConvoKitMeta({'movie_idx': 'm123', 'movie_name': 'lost highway', 'release_year': '1997', 'rating': '7.60', 'votes': '42998', 'genre': "['drama', 'horror', 'mystery', 'thriller']"})
# Number of utterances in conversation: 4
#
# Conversation ID: L356099
# Metadata: ConvoKitMeta({'movie_idx': 'm123', 'movie_name': 'lost highway', 'release_year': '1997', 'rating': '7.60', 'votes': '42998', 'genre': "['drama', 'horror', 'mystery', 'thriller']"})
# Number of utterances in conversation: 8
#
# Conversation ID: L356097
# Metadata: ConvoKitMeta({'movie_idx': 'm123', 'movie_name': 'lost highway', 'release_year': '1997', 'rating': '7.60', 'votes': '42998', 'genre': "['drama', 'horror', 'mystery', 'thriller']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L356086
# Metadata: ConvoKitMeta({'movie_idx': 'm123', 'movie_name': 'lost highway', 'release_year': '1997', 'rating': '7.60', 'votes': '42998', 'genre': "['drama', 'horror', 'mystery', 'thriller']"})
# Number of utterances in conversation: 9
#
# Conversation ID: L356084
# Metadata: ConvoKitMeta({'movie_idx': 'm123', 'movie_name': 'lost highway', 'release_year': '1997', 'rating': '7.60', 'votes': '42998', 'genre': "['drama', 'horror', 'mystery', 'thriller']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L356077
# Metadata: ConvoKitMeta({'movie_idx': 'm123', 'movie_name': 'lost highway', 'release_year': '1997', 'rating': '7.60', 'votes': '42998', 'genre': "['drama', 'horror', 'mystery', 'thriller']"})
# Number of utterances in conversation: 4
#
# Conversation ID: L356072
# Metadata: ConvoKitMeta({'movie_idx': 'm123', 'movie_name': 'lost highway', 'release_year': '1997', 'rating': '7.60', 'votes': '42998', 'genre': "['drama', 'horror', 'mystery', 'thriller']"})
# Number of utterances in conversation: 3
#
# Conversation ID: L357775
# Metadata: ConvoKitMeta({'movie_idx': 'm124', 'movie_name': 'lost horizon', 'release_year': '1937', 'rating': '7.80', 'votes': '5509', 'genre': "['adventure', 'drama', 'fantasy', 'mystery']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L357771
# Metadata: ConvoKitMeta({'movie_idx': 'm124', 'movie_name': 'lost horizon', 'release_year': '1937', 'rating': '7.80', 'votes': '5509', 'genre': "['adventure', 'drama', 'fantasy', 'mystery']"})
# Number of utterances in conversation: 4
#
# Conversation ID: L357766
# Metadata: ConvoKitMeta({'movie_idx': 'm124', 'movie_name': 'lost horizon', 'release_year': '1937', 'rating': '7.80', 'votes': '5509', 'genre': "['adventure', 'drama', 'fantasy', 'mystery']"})
# Number of utterances in conversation: 3
#
# Conversation ID: L357225
# Metadata: ConvoKitMeta({'movie_idx': 'm124', 'movie_name': 'lost horizon', 'release_year': '1937', 'rating': '7.80', 'votes': '5509', 'genre': "['adventure', 'drama', 'fantasy', 'mystery']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L357217
# Metadata: ConvoKitMeta({'movie_idx': 'm124', 'movie_name': 'lost horizon', 'release_year': '1937', 'rating': '7.80', 'votes': '5509', 'genre': "['adventure', 'drama', 'fantasy', 'mystery']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L357207
# Metadata: ConvoKitMeta({'movie_idx': 'm124', 'movie_name': 'lost horizon', 'release_year': '1937', 'rating': '7.80', 'votes': '5509', 'genre': "['adventure', 'drama', 'fantasy', 'mystery']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L357200
# Metadata: ConvoKitMeta({'movie_idx': 'm124', 'movie_name': 'lost horizon', 'release_year': '1937', 'rating': '7.80', 'votes': '5509', 'genre': "['adventure', 'drama', 'fantasy', 'mystery']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L357198
# Metadata: ConvoKitMeta({'movie_idx': 'm124', 'movie_name': 'lost horizon', 'release_year': '1937', 'rating': '7.80', 'votes': '5509', 'genre': "['adventure', 'drama', 'fantasy', 'mystery']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L357660
# Metadata: ConvoKitMeta({'movie_idx': 'm124', 'movie_name': 'lost horizon', 'release_year': '1937', 'rating': '7.80', 'votes': '5509', 'genre': "['adventure', 'drama', 'fantasy', 'mystery']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L357522
# Metadata: ConvoKitMeta({'movie_idx': 'm124', 'movie_name': 'lost horizon', 'release_year': '1937', 'rating': '7.80', 'votes': '5509', 'genre': "['adventure', 'drama', 'fantasy', 'mystery']"})
# Number of utterances in conversation: 6
#
# Conversation ID: L357519
# Metadata: ConvoKitMeta({'movie_idx': 'm124', 'movie_name': 'lost horizon', 'release_year': '1937', 'rating': '7.80', 'votes': '5509', 'genre': "['adventure', 'drama', 'fantasy', 'mystery']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L357512
# Metadata: ConvoKitMeta({'movie_idx': 'm124', 'movie_name': 'lost horizon', 'release_year': '1937', 'rating': '7.80', 'votes': '5509', 'genre': "['adventure', 'drama', 'fantasy', 'mystery']"})
# Number of utterances in conversation: 5
#
# Conversation ID: L357505
# Metadata: ConvoKitMeta({'movie_idx': 'm124', 'movie_name': 'lost horizon', 'release_year': '1937', 'rating': '7.80', 'votes': '5509', 'genre': "['adventure', 'drama', 'fantasy', 'mystery']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L357498
# Metadata: ConvoKitMeta({'movie_idx': 'm124', 'movie_name': 'lost horizon', 'release_year': '1937', 'rating': '7.80', 'votes': '5509', 'genre': "['adventure', 'drama', 'fantasy', 'mystery']"})
# Number of utterances in conversation: 7
#
# Conversation ID: L357407
# Metadata: ConvoKitMeta({'movie_idx': 'm124', 'movie_name': 'lost horizon', 'release_year': '1937', 'rating': '7.80', 'votes': '5509', 'genre': "['adventure', 'drama', 'fantasy', 'mystery']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L357374
# Metadata: ConvoKitMeta({'movie_idx': 'm124', 'movie_name': 'lost horizon', 'release_year': '1937', 'rating': '7.80', 'votes': '5509', 'genre': "['adventure', 'drama', 'fantasy', 'mystery']"})
# Number of utterances in conversation: 4
#
# Conversation ID: L357365
# Metadata: ConvoKitMeta({'movie_idx': 'm124', 'movie_name': 'lost horizon', 'release_year': '1937', 'rating': '7.80', 'votes': '5509', 'genre': "['adventure', 'drama', 'fantasy', 'mystery']"})
# Number of utterances in conversation: 4
#
# Conversation ID: L357359
# Metadata: ConvoKitMeta({'movie_idx': 'm124', 'movie_name': 'lost horizon', 'release_year': '1937', 'rating': '7.80', 'votes': '5509', 'genre': "['adventure', 'drama', 'fantasy', 'mystery']"})
# Number of utterances in conversation: 4
#
# Conversation ID: L357235
# Metadata: ConvoKitMeta({'movie_idx': 'm124', 'movie_name': 'lost horizon', 'release_year': '1937', 'rating': '7.80', 'votes': '5509', 'genre': "['adventure', 'drama', 'fantasy', 'mystery']"})
# Number of utterances in conversation: 7
#
# Conversation ID: L357178
# Metadata: ConvoKitMeta({'movie_idx': 'm124', 'movie_name': 'lost horizon', 'release_year': '1937', 'rating': '7.80', 'votes': '5509', 'genre': "['adventure', 'drama', 'fantasy', 'mystery']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L357176
# Metadata: ConvoKitMeta({'movie_idx': 'm124', 'movie_name': 'lost horizon', 'release_year': '1937', 'rating': '7.80', 'votes': '5509', 'genre': "['adventure', 'drama', 'fantasy', 'mystery']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L357171
# Metadata: ConvoKitMeta({'movie_idx': 'm124', 'movie_name': 'lost horizon', 'release_year': '1937', 'rating': '7.80', 'votes': '5509', 'genre': "['adventure', 'drama', 'fantasy', 'mystery']"})
# Number of utterances in conversation: 4
#
# Conversation ID: L357169
# Metadata: ConvoKitMeta({'movie_idx': 'm124', 'movie_name': 'lost horizon', 'release_year': '1937', 'rating': '7.80', 'votes': '5509', 'genre': "['adventure', 'drama', 'fantasy', 'mystery']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L357165
# Metadata: ConvoKitMeta({'movie_idx': 'm124', 'movie_name': 'lost horizon', 'release_year': '1937', 'rating': '7.80', 'votes': '5509', 'genre': "['adventure', 'drama', 'fantasy', 'mystery']"})
# Number of utterances in conversation: 4
#
# Conversation ID: L357141
# Metadata: ConvoKitMeta({'movie_idx': 'm124', 'movie_name': 'lost horizon', 'release_year': '1937', 'rating': '7.80', 'votes': '5509', 'genre': "['adventure', 'drama', 'fantasy', 'mystery']"})
# Number of utterances in conversation: 3
#
# Conversation ID: L357123
# Metadata: ConvoKitMeta({'movie_idx': 'm124', 'movie_name': 'lost horizon', 'release_year': '1937', 'rating': '7.80', 'votes': '5509', 'genre': "['adventure', 'drama', 'fantasy', 'mystery']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L357041
# Metadata: ConvoKitMeta({'movie_idx': 'm124', 'movie_name': 'lost horizon', 'release_year': '1937', 'rating': '7.80', 'votes': '5509', 'genre': "['adventure', 'drama', 'fantasy', 'mystery']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L357027
# Metadata: ConvoKitMeta({'movie_idx': 'm124', 'movie_name': 'lost horizon', 'release_year': '1937', 'rating': '7.80', 'votes': '5509', 'genre': "['adventure', 'drama', 'fantasy', 'mystery']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L357008
# Metadata: ConvoKitMeta({'movie_idx': 'm124', 'movie_name': 'lost horizon', 'release_year': '1937', 'rating': '7.80', 'votes': '5509', 'genre': "['adventure', 'drama', 'fantasy', 'mystery']"})
# Number of utterances in conversation: 14
#
# Conversation ID: L357003
# Metadata: ConvoKitMeta({'movie_idx': 'm124', 'movie_name': 'lost horizon', 'release_year': '1937', 'rating': '7.80', 'votes': '5509', 'genre': "['adventure', 'drama', 'fantasy', 'mystery']"})
# Number of utterances in conversation: 5
#
# Conversation ID: L356997
# Metadata: ConvoKitMeta({'movie_idx': 'm124', 'movie_name': 'lost horizon', 'release_year': '1937', 'rating': '7.80', 'votes': '5509', 'genre': "['adventure', 'drama', 'fantasy', 'mystery']"})
# Number of utterances in conversation: 4
#
# Conversation ID: L356967
# Metadata: ConvoKitMeta({'movie_idx': 'm124', 'movie_name': 'lost horizon', 'release_year': '1937', 'rating': '7.80', 'votes': '5509', 'genre': "['adventure', 'drama', 'fantasy', 'mystery']"})
# Number of utterances in conversation: 4
#
# Conversation ID: L356958
# Metadata: ConvoKitMeta({'movie_idx': 'm124', 'movie_name': 'lost horizon', 'release_year': '1937', 'rating': '7.80', 'votes': '5509', 'genre': "['adventure', 'drama', 'fantasy', 'mystery']"})
# Number of utterances in conversation: 8
#
# Conversation ID: L356951
# Metadata: ConvoKitMeta({'movie_idx': 'm124', 'movie_name': 'lost horizon', 'release_year': '1937', 'rating': '7.80', 'votes': '5509', 'genre': "['adventure', 'drama', 'fantasy', 'mystery']"})
# Number of utterances in conversation: 7
#
# Conversation ID: L356944
# Metadata: ConvoKitMeta({'movie_idx': 'm124', 'movie_name': 'lost horizon', 'release_year': '1937', 'rating': '7.80', 'votes': '5509', 'genre': "['adventure', 'drama', 'fantasy', 'mystery']"})
# Number of utterances in conversation: 7
#
# Conversation ID: L357583
# Metadata: ConvoKitMeta({'movie_idx': 'm124', 'movie_name': 'lost horizon', 'release_year': '1937', 'rating': '7.80', 'votes': '5509', 'genre': "['adventure', 'drama', 'fantasy', 'mystery']"})
# Number of utterances in conversation: 8
#
# Conversation ID: L357403
# Metadata: ConvoKitMeta({'movie_idx': 'm124', 'movie_name': 'lost horizon', 'release_year': '1937', 'rating': '7.80', 'votes': '5509', 'genre': "['adventure', 'drama', 'fantasy', 'mystery']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L357369
# Metadata: ConvoKitMeta({'movie_idx': 'm124', 'movie_name': 'lost horizon', 'release_year': '1937', 'rating': '7.80', 'votes': '5509', 'genre': "['adventure', 'drama', 'fantasy', 'mystery']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L357363
# Metadata: ConvoKitMeta({'movie_idx': 'm124', 'movie_name': 'lost horizon', 'release_year': '1937', 'rating': '7.80', 'votes': '5509', 'genre': "['adventure', 'drama', 'fantasy', 'mystery']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L357350
# Metadata: ConvoKitMeta({'movie_idx': 'm124', 'movie_name': 'lost horizon', 'release_year': '1937', 'rating': '7.80', 'votes': '5509', 'genre': "['adventure', 'drama', 'fantasy', 'mystery']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L357233
# Metadata: ConvoKitMeta({'movie_idx': 'm124', 'movie_name': 'lost horizon', 'release_year': '1937', 'rating': '7.80', 'votes': '5509', 'genre': "['adventure', 'drama', 'fantasy', 'mystery']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L357180
# Metadata: ConvoKitMeta({'movie_idx': 'm124', 'movie_name': 'lost horizon', 'release_year': '1937', 'rating': '7.80', 'votes': '5509', 'genre': "['adventure', 'drama', 'fantasy', 'mystery']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L357114
# Metadata: ConvoKitMeta({'movie_idx': 'm124', 'movie_name': 'lost horizon', 'release_year': '1937', 'rating': '7.80', 'votes': '5509', 'genre': "['adventure', 'drama', 'fantasy', 'mystery']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L357039
# Metadata: ConvoKitMeta({'movie_idx': 'm124', 'movie_name': 'lost horizon', 'release_year': '1937', 'rating': '7.80', 'votes': '5509', 'genre': "['adventure', 'drama', 'fantasy', 'mystery']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L357037
# Metadata: ConvoKitMeta({'movie_idx': 'm124', 'movie_name': 'lost horizon', 'release_year': '1937', 'rating': '7.80', 'votes': '5509', 'genre': "['adventure', 'drama', 'fantasy', 'mystery']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L357644
# Metadata: ConvoKitMeta({'movie_idx': 'm124', 'movie_name': 'lost horizon', 'release_year': '1937', 'rating': '7.80', 'votes': '5509', 'genre': "['adventure', 'drama', 'fantasy', 'mystery']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L357629
# Metadata: ConvoKitMeta({'movie_idx': 'm124', 'movie_name': 'lost horizon', 'release_year': '1937', 'rating': '7.80', 'votes': '5509', 'genre': "['adventure', 'drama', 'fantasy', 'mystery']"})
# Number of utterances in conversation: 3
#
# Conversation ID: L357354
# Metadata: ConvoKitMeta({'movie_idx': 'm124', 'movie_name': 'lost horizon', 'release_year': '1937', 'rating': '7.80', 'votes': '5509', 'genre': "['adventure', 'drama', 'fantasy', 'mystery']"})
# Number of utterances in conversation: 3
#
# Conversation ID: L356972
# Metadata: ConvoKitMeta({'movie_idx': 'm124', 'movie_name': 'lost horizon', 'release_year': '1937', 'rating': '7.80', 'votes': '5509', 'genre': "['adventure', 'drama', 'fantasy', 'mystery']"})
# Number of utterances in conversation: 4
#
# Conversation ID: L357632
# Metadata: ConvoKitMeta({'movie_idx': 'm124', 'movie_name': 'lost horizon', 'release_year': '1937', 'rating': '7.80', 'votes': '5509', 'genre': "['adventure', 'drama', 'fantasy', 'mystery']"})
# Number of utterances in conversation: 12
#
# Conversation ID: L357139
# Metadata: ConvoKitMeta({'movie_idx': 'm124', 'movie_name': 'lost horizon', 'release_year': '1937', 'rating': '7.80', 'votes': '5509', 'genre': "['adventure', 'drama', 'fantasy', 'mystery']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L357137
# Metadata: ConvoKitMeta({'movie_idx': 'm124', 'movie_name': 'lost horizon', 'release_year': '1937', 'rating': '7.80', 'votes': '5509', 'genre': "['adventure', 'drama', 'fantasy', 'mystery']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L357618
# Metadata: ConvoKitMeta({'movie_idx': 'm124', 'movie_name': 'lost horizon', 'release_year': '1937', 'rating': '7.80', 'votes': '5509', 'genre': "['adventure', 'drama', 'fantasy', 'mystery']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L357601
# Metadata: ConvoKitMeta({'movie_idx': 'm124', 'movie_name': 'lost horizon', 'release_year': '1937', 'rating': '7.80', 'votes': '5509', 'genre': "['adventure', 'drama', 'fantasy', 'mystery']"})
# Number of utterances in conversation: 13
#
# Conversation ID: L357596
# Metadata: ConvoKitMeta({'movie_idx': 'm124', 'movie_name': 'lost horizon', 'release_year': '1937', 'rating': '7.80', 'votes': '5509', 'genre': "['adventure', 'drama', 'fantasy', 'mystery']"})
# Number of utterances in conversation: 3
#
# Conversation ID: L357409
# Metadata: ConvoKitMeta({'movie_idx': 'm124', 'movie_name': 'lost horizon', 'release_year': '1937', 'rating': '7.80', 'votes': '5509', 'genre': "['adventure', 'drama', 'fantasy', 'mystery']"})
# Number of utterances in conversation: 5
#
# Conversation ID: L357305
# Metadata: ConvoKitMeta({'movie_idx': 'm124', 'movie_name': 'lost horizon', 'release_year': '1937', 'rating': '7.80', 'votes': '5509', 'genre': "['adventure', 'drama', 'fantasy', 'mystery']"})
# Number of utterances in conversation: 28
#
# Conversation ID: L357299
# Metadata: ConvoKitMeta({'movie_idx': 'm124', 'movie_name': 'lost horizon', 'release_year': '1937', 'rating': '7.80', 'votes': '5509', 'genre': "['adventure', 'drama', 'fantasy', 'mystery']"})
# Number of utterances in conversation: 6
#
# Conversation ID: L357284
# Metadata: ConvoKitMeta({'movie_idx': 'm124', 'movie_name': 'lost horizon', 'release_year': '1937', 'rating': '7.80', 'votes': '5509', 'genre': "['adventure', 'drama', 'fantasy', 'mystery']"})
# Number of utterances in conversation: 13
#
# Conversation ID: L357282
# Metadata: ConvoKitMeta({'movie_idx': 'm124', 'movie_name': 'lost horizon', 'release_year': '1937', 'rating': '7.80', 'votes': '5509', 'genre': "['adventure', 'drama', 'fantasy', 'mystery']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L357272
# Metadata: ConvoKitMeta({'movie_idx': 'm124', 'movie_name': 'lost horizon', 'release_year': '1937', 'rating': '7.80', 'votes': '5509', 'genre': "['adventure', 'drama', 'fantasy', 'mystery']"})
# Number of utterances in conversation: 4
#
# Conversation ID: L357265
# Metadata: ConvoKitMeta({'movie_idx': 'm124', 'movie_name': 'lost horizon', 'release_year': '1937', 'rating': '7.80', 'votes': '5509', 'genre': "['adventure', 'drama', 'fantasy', 'mystery']"})
# Number of utterances in conversation: 7
#
# Conversation ID: L357202
# Metadata: ConvoKitMeta({'movie_idx': 'm124', 'movie_name': 'lost horizon', 'release_year': '1937', 'rating': '7.80', 'votes': '5509', 'genre': "['adventure', 'drama', 'fantasy', 'mystery']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L357159
# Metadata: ConvoKitMeta({'movie_idx': 'm124', 'movie_name': 'lost horizon', 'release_year': '1937', 'rating': '7.80', 'votes': '5509', 'genre': "['adventure', 'drama', 'fantasy', 'mystery']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L357153
# Metadata: ConvoKitMeta({'movie_idx': 'm124', 'movie_name': 'lost horizon', 'release_year': '1937', 'rating': '7.80', 'votes': '5509', 'genre': "['adventure', 'drama', 'fantasy', 'mystery']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L357148
# Metadata: ConvoKitMeta({'movie_idx': 'm124', 'movie_name': 'lost horizon', 'release_year': '1937', 'rating': '7.80', 'votes': '5509', 'genre': "['adventure', 'drama', 'fantasy', 'mystery']"})
# Number of utterances in conversation: 3
#
# Conversation ID: L357186
# Metadata: ConvoKitMeta({'movie_idx': 'm124', 'movie_name': 'lost horizon', 'release_year': '1937', 'rating': '7.80', 'votes': '5509', 'genre': "['adventure', 'drama', 'fantasy', 'mystery']"})
# Number of utterances in conversation: 8
#
# Conversation ID: L357183
# Metadata: ConvoKitMeta({'movie_idx': 'm124', 'movie_name': 'lost horizon', 'release_year': '1937', 'rating': '7.80', 'votes': '5509', 'genre': "['adventure', 'drama', 'fantasy', 'mystery']"})
# Number of utterances in conversation: 3
#
# Conversation ID: L357565
# Metadata: ConvoKitMeta({'movie_idx': 'm124', 'movie_name': 'lost horizon', 'release_year': '1937', 'rating': '7.80', 'votes': '5509', 'genre': "['adventure', 'drama', 'fantasy', 'mystery']"})
# Number of utterances in conversation: 18
#
# Conversation ID: L357401
# Metadata: ConvoKitMeta({'movie_idx': 'm124', 'movie_name': 'lost horizon', 'release_year': '1937', 'rating': '7.80', 'votes': '5509', 'genre': "['adventure', 'drama', 'fantasy', 'mystery']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L357223
# Metadata: ConvoKitMeta({'movie_idx': 'm124', 'movie_name': 'lost horizon', 'release_year': '1937', 'rating': '7.80', 'votes': '5509', 'genre': "['adventure', 'drama', 'fantasy', 'mystery']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L357213
# Metadata: ConvoKitMeta({'movie_idx': 'm124', 'movie_name': 'lost horizon', 'release_year': '1937', 'rating': '7.80', 'votes': '5509', 'genre': "['adventure', 'drama', 'fantasy', 'mystery']"})
# Number of utterances in conversation: 4
#
# Conversation ID: L357615
# Metadata: ConvoKitMeta({'movie_idx': 'm124', 'movie_name': 'lost horizon', 'release_year': '1937', 'rating': '7.80', 'votes': '5509', 'genre': "['adventure', 'drama', 'fantasy', 'mystery']"})
# Number of utterances in conversation: 3
#
# Conversation ID: L357405
# Metadata: ConvoKitMeta({'movie_idx': 'm124', 'movie_name': 'lost horizon', 'release_year': '1937', 'rating': '7.80', 'votes': '5509', 'genre': "['adventure', 'drama', 'fantasy', 'mystery']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L357220
# Metadata: ConvoKitMeta({'movie_idx': 'm124', 'movie_name': 'lost horizon', 'release_year': '1937', 'rating': '7.80', 'votes': '5509', 'genre': "['adventure', 'drama', 'fantasy', 'mystery']"})
# Number of utterances in conversation: 3
#
# Conversation ID: L357209
# Metadata: ConvoKitMeta({'movie_idx': 'm124', 'movie_name': 'lost horizon', 'release_year': '1937', 'rating': '7.80', 'votes': '5509', 'genre': "['adventure', 'drama', 'fantasy', 'mystery']"})
# Number of utterances in conversation: 4
#
# Conversation ID: L357155
# Metadata: ConvoKitMeta({'movie_idx': 'm124', 'movie_name': 'lost horizon', 'release_year': '1937', 'rating': '7.80', 'votes': '5509', 'genre': "['adventure', 'drama', 'fantasy', 'mystery']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L357760
# Metadata: ConvoKitMeta({'movie_idx': 'm124', 'movie_name': 'lost horizon', 'release_year': '1937', 'rating': '7.80', 'votes': '5509', 'genre': "['adventure', 'drama', 'fantasy', 'mystery']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L357742
# Metadata: ConvoKitMeta({'movie_idx': 'm124', 'movie_name': 'lost horizon', 'release_year': '1937', 'rating': '7.80', 'votes': '5509', 'genre': "['adventure', 'drama', 'fantasy', 'mystery']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L357733
# Metadata: ConvoKitMeta({'movie_idx': 'm124', 'movie_name': 'lost horizon', 'release_year': '1937', 'rating': '7.80', 'votes': '5509', 'genre': "['adventure', 'drama', 'fantasy', 'mystery']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L357720
# Metadata: ConvoKitMeta({'movie_idx': 'm124', 'movie_name': 'lost horizon', 'release_year': '1937', 'rating': '7.80', 'votes': '5509', 'genre': "['adventure', 'drama', 'fantasy', 'mystery']"})
# Number of utterances in conversation: 11
#
# Conversation ID: L357427
# Metadata: ConvoKitMeta({'movie_idx': 'm124', 'movie_name': 'lost horizon', 'release_year': '1937', 'rating': '7.80', 'votes': '5509', 'genre': "['adventure', 'drama', 'fantasy', 'mystery']"})
# Number of utterances in conversation: 9
#
# Conversation ID: L357422
# Metadata: ConvoKitMeta({'movie_idx': 'm124', 'movie_name': 'lost horizon', 'release_year': '1937', 'rating': '7.80', 'votes': '5509', 'genre': "['adventure', 'drama', 'fantasy', 'mystery']"})
# Number of utterances in conversation: 4
#
# Conversation ID: L357420
# Metadata: ConvoKitMeta({'movie_idx': 'm124', 'movie_name': 'lost horizon', 'release_year': '1937', 'rating': '7.80', 'votes': '5509', 'genre': "['adventure', 'drama', 'fantasy', 'mystery']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L357417
# Metadata: ConvoKitMeta({'movie_idx': 'm124', 'movie_name': 'lost horizon', 'release_year': '1937', 'rating': '7.80', 'votes': '5509', 'genre': "['adventure', 'drama', 'fantasy', 'mystery']"})
# Number of utterances in conversation: 3
#
# Conversation ID: L357626
# Metadata: ConvoKitMeta({'movie_idx': 'm124', 'movie_name': 'lost horizon', 'release_year': '1937', 'rating': '7.80', 'votes': '5509', 'genre': "['adventure', 'drama', 'fantasy', 'mystery']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L357620
# Metadata: ConvoKitMeta({'movie_idx': 'm124', 'movie_name': 'lost horizon', 'release_year': '1937', 'rating': '7.80', 'votes': '5509', 'genre': "['adventure', 'drama', 'fantasy', 'mystery']"})
# Number of utterances in conversation: 5
#
# Conversation ID: L357762
# Metadata: ConvoKitMeta({'movie_idx': 'm124', 'movie_name': 'lost horizon', 'release_year': '1937', 'rating': '7.80', 'votes': '5509', 'genre': "['adventure', 'drama', 'fantasy', 'mystery']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L357758
# Metadata: ConvoKitMeta({'movie_idx': 'm124', 'movie_name': 'lost horizon', 'release_year': '1937', 'rating': '7.80', 'votes': '5509', 'genre': "['adventure', 'drama', 'fantasy', 'mystery']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L357747
# Metadata: ConvoKitMeta({'movie_idx': 'm124', 'movie_name': 'lost horizon', 'release_year': '1937', 'rating': '7.80', 'votes': '5509', 'genre': "['adventure', 'drama', 'fantasy', 'mystery']"})
# Number of utterances in conversation: 4
#
# Conversation ID: L357735
# Metadata: ConvoKitMeta({'movie_idx': 'm124', 'movie_name': 'lost horizon', 'release_year': '1937', 'rating': '7.80', 'votes': '5509', 'genre': "['adventure', 'drama', 'fantasy', 'mystery']"})
# Number of utterances in conversation: 7
#
# Conversation ID: L357731
# Metadata: ConvoKitMeta({'movie_idx': 'm124', 'movie_name': 'lost horizon', 'release_year': '1937', 'rating': '7.80', 'votes': '5509', 'genre': "['adventure', 'drama', 'fantasy', 'mystery']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L357712
# Metadata: ConvoKitMeta({'movie_idx': 'm124', 'movie_name': 'lost horizon', 'release_year': '1937', 'rating': '7.80', 'votes': '5509', 'genre': "['adventure', 'drama', 'fantasy', 'mystery']"})
# Number of utterances in conversation: 3
#
# Conversation ID: L357709
# Metadata: ConvoKitMeta({'movie_idx': 'm124', 'movie_name': 'lost horizon', 'release_year': '1937', 'rating': '7.80', 'votes': '5509', 'genre': "['adventure', 'drama', 'fantasy', 'mystery']"})
# Number of utterances in conversation: 3
#
# Conversation ID: L357704
# Metadata: ConvoKitMeta({'movie_idx': 'm124', 'movie_name': 'lost horizon', 'release_year': '1937', 'rating': '7.80', 'votes': '5509', 'genre': "['adventure', 'drama', 'fantasy', 'mystery']"})
# Number of utterances in conversation: 5
#
# Conversation ID: L357697
# Metadata: ConvoKitMeta({'movie_idx': 'm124', 'movie_name': 'lost horizon', 'release_year': '1937', 'rating': '7.80', 'votes': '5509', 'genre': "['adventure', 'drama', 'fantasy', 'mystery']"})
# Number of utterances in conversation: 6
#
# Conversation ID: L357690
# Metadata: ConvoKitMeta({'movie_idx': 'm124', 'movie_name': 'lost horizon', 'release_year': '1937', 'rating': '7.80', 'votes': '5509', 'genre': "['adventure', 'drama', 'fantasy', 'mystery']"})
# Number of utterances in conversation: 7
#
# Conversation ID: L357674
# Metadata: ConvoKitMeta({'movie_idx': 'm124', 'movie_name': 'lost horizon', 'release_year': '1937', 'rating': '7.80', 'votes': '5509', 'genre': "['adventure', 'drama', 'fantasy', 'mystery']"})
# Number of utterances in conversation: 16
#
# Conversation ID: L357670
# Metadata: ConvoKitMeta({'movie_idx': 'm124', 'movie_name': 'lost horizon', 'release_year': '1937', 'rating': '7.80', 'votes': '5509', 'genre': "['adventure', 'drama', 'fantasy', 'mystery']"})
# Number of utterances in conversation: 3
#
# Conversation ID: L357665
# Metadata: ConvoKitMeta({'movie_idx': 'm124', 'movie_name': 'lost horizon', 'release_year': '1937', 'rating': '7.80', 'votes': '5509', 'genre': "['adventure', 'drama', 'fantasy', 'mystery']"})
# Number of utterances in conversation: 5
#
# Conversation ID: L357593
# Metadata: ConvoKitMeta({'movie_idx': 'm124', 'movie_name': 'lost horizon', 'release_year': '1937', 'rating': '7.80', 'votes': '5509', 'genre': "['adventure', 'drama', 'fantasy', 'mystery']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L357444
# Metadata: ConvoKitMeta({'movie_idx': 'm124', 'movie_name': 'lost horizon', 'release_year': '1937', 'rating': '7.80', 'votes': '5509', 'genre': "['adventure', 'drama', 'fantasy', 'mystery']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L357439
# Metadata: ConvoKitMeta({'movie_idx': 'm124', 'movie_name': 'lost horizon', 'release_year': '1937', 'rating': '7.80', 'votes': '5509', 'genre': "['adventure', 'drama', 'fantasy', 'mystery']"})
# Number of utterances in conversation: 4
#
# Conversation ID: L357391
# Metadata: ConvoKitMeta({'movie_idx': 'm124', 'movie_name': 'lost horizon', 'release_year': '1937', 'rating': '7.80', 'votes': '5509', 'genre': "['adventure', 'drama', 'fantasy', 'mystery']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L357386
# Metadata: ConvoKitMeta({'movie_idx': 'm124', 'movie_name': 'lost horizon', 'release_year': '1937', 'rating': '7.80', 'votes': '5509', 'genre': "['adventure', 'drama', 'fantasy', 'mystery']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L357384
# Metadata: ConvoKitMeta({'movie_idx': 'm124', 'movie_name': 'lost horizon', 'release_year': '1937', 'rating': '7.80', 'votes': '5509', 'genre': "['adventure', 'drama', 'fantasy', 'mystery']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L357343
# Metadata: ConvoKitMeta({'movie_idx': 'm124', 'movie_name': 'lost horizon', 'release_year': '1937', 'rating': '7.80', 'votes': '5509', 'genre': "['adventure', 'drama', 'fantasy', 'mystery']"})
# Number of utterances in conversation: 7
#
# Conversation ID: L357252
# Metadata: ConvoKitMeta({'movie_idx': 'm124', 'movie_name': 'lost horizon', 'release_year': '1937', 'rating': '7.80', 'votes': '5509', 'genre': "['adventure', 'drama', 'fantasy', 'mystery']"})
# Number of utterances in conversation: 13
#
# Conversation ID: L357242
# Metadata: ConvoKitMeta({'movie_idx': 'm124', 'movie_name': 'lost horizon', 'release_year': '1937', 'rating': '7.80', 'votes': '5509', 'genre': "['adventure', 'drama', 'fantasy', 'mystery']"})
# Number of utterances in conversation: 10
#
# Conversation ID: L357103
# Metadata: ConvoKitMeta({'movie_idx': 'm124', 'movie_name': 'lost horizon', 'release_year': '1937', 'rating': '7.80', 'votes': '5509', 'genre': "['adventure', 'drama', 'fantasy', 'mystery']"})
# Number of utterances in conversation: 6
#
# Conversation ID: L357100
# Metadata: ConvoKitMeta({'movie_idx': 'm124', 'movie_name': 'lost horizon', 'release_year': '1937', 'rating': '7.80', 'votes': '5509', 'genre': "['adventure', 'drama', 'fantasy', 'mystery']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L357097
# Metadata: ConvoKitMeta({'movie_idx': 'm124', 'movie_name': 'lost horizon', 'release_year': '1937', 'rating': '7.80', 'votes': '5509', 'genre': "['adventure', 'drama', 'fantasy', 'mystery']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L357083
# Metadata: ConvoKitMeta({'movie_idx': 'm124', 'movie_name': 'lost horizon', 'release_year': '1937', 'rating': '7.80', 'votes': '5509', 'genre': "['adventure', 'drama', 'fantasy', 'mystery']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L357063
# Metadata: ConvoKitMeta({'movie_idx': 'm124', 'movie_name': 'lost horizon', 'release_year': '1937', 'rating': '7.80', 'votes': '5509', 'genre': "['adventure', 'drama', 'fantasy', 'mystery']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L357047
# Metadata: ConvoKitMeta({'movie_idx': 'm124', 'movie_name': 'lost horizon', 'release_year': '1937', 'rating': '7.80', 'votes': '5509', 'genre': "['adventure', 'drama', 'fantasy', 'mystery']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L357033
# Metadata: ConvoKitMeta({'movie_idx': 'm124', 'movie_name': 'lost horizon', 'release_year': '1937', 'rating': '7.80', 'votes': '5509', 'genre': "['adventure', 'drama', 'fantasy', 'mystery']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L356993
# Metadata: ConvoKitMeta({'movie_idx': 'm124', 'movie_name': 'lost horizon', 'release_year': '1937', 'rating': '7.80', 'votes': '5509', 'genre': "['adventure', 'drama', 'fantasy', 'mystery']"})
# Number of utterances in conversation: 3
#
# Conversation ID: L356985
# Metadata: ConvoKitMeta({'movie_idx': 'm124', 'movie_name': 'lost horizon', 'release_year': '1937', 'rating': '7.80', 'votes': '5509', 'genre': "['adventure', 'drama', 'fantasy', 'mystery']"})
# Number of utterances in conversation: 7
#
# Conversation ID: L356980
# Metadata: ConvoKitMeta({'movie_idx': 'm124', 'movie_name': 'lost horizon', 'release_year': '1937', 'rating': '7.80', 'votes': '5509', 'genre': "['adventure', 'drama', 'fantasy', 'mystery']"})
# Number of utterances in conversation: 3
#
# Conversation ID: L356977
# Metadata: ConvoKitMeta({'movie_idx': 'm124', 'movie_name': 'lost horizon', 'release_year': '1937', 'rating': '7.80', 'votes': '5509', 'genre': "['adventure', 'drama', 'fantasy', 'mystery']"})
# Number of utterances in conversation: 3
#
# Conversation ID: L356942
# Metadata: ConvoKitMeta({'movie_idx': 'm124', 'movie_name': 'lost horizon', 'release_year': '1937', 'rating': '7.80', 'votes': '5509', 'genre': "['adventure', 'drama', 'fantasy', 'mystery']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L356925
# Metadata: ConvoKitMeta({'movie_idx': 'm124', 'movie_name': 'lost horizon', 'release_year': '1937', 'rating': '7.80', 'votes': '5509', 'genre': "['adventure', 'drama', 'fantasy', 'mystery']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L356920
# Metadata: ConvoKitMeta({'movie_idx': 'm124', 'movie_name': 'lost horizon', 'release_year': '1937', 'rating': '7.80', 'votes': '5509', 'genre': "['adventure', 'drama', 'fantasy', 'mystery']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L356918
# Metadata: ConvoKitMeta({'movie_idx': 'm124', 'movie_name': 'lost horizon', 'release_year': '1937', 'rating': '7.80', 'votes': '5509', 'genre': "['adventure', 'drama', 'fantasy', 'mystery']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L356902
# Metadata: ConvoKitMeta({'movie_idx': 'm124', 'movie_name': 'lost horizon', 'release_year': '1937', 'rating': '7.80', 'votes': '5509', 'genre': "['adventure', 'drama', 'fantasy', 'mystery']"})
# Number of utterances in conversation: 3
#
# Conversation ID: L356899
# Metadata: ConvoKitMeta({'movie_idx': 'm124', 'movie_name': 'lost horizon', 'release_year': '1937', 'rating': '7.80', 'votes': '5509', 'genre': "['adventure', 'drama', 'fantasy', 'mystery']"})
# Number of utterances in conversation: 3
#
# Conversation ID: L357151
# Metadata: ConvoKitMeta({'movie_idx': 'm124', 'movie_name': 'lost horizon', 'release_year': '1937', 'rating': '7.80', 'votes': '5509', 'genre': "['adventure', 'drama', 'fantasy', 'mystery']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L357079
# Metadata: ConvoKitMeta({'movie_idx': 'm124', 'movie_name': 'lost horizon', 'release_year': '1937', 'rating': '7.80', 'votes': '5509', 'genre': "['adventure', 'drama', 'fantasy', 'mystery']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L357066
# Metadata: ConvoKitMeta({'movie_idx': 'm124', 'movie_name': 'lost horizon', 'release_year': '1937', 'rating': '7.80', 'votes': '5509', 'genre': "['adventure', 'drama', 'fantasy', 'mystery']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L357054
# Metadata: ConvoKitMeta({'movie_idx': 'm124', 'movie_name': 'lost horizon', 'release_year': '1937', 'rating': '7.80', 'votes': '5509', 'genre': "['adventure', 'drama', 'fantasy', 'mystery']"})
# Number of utterances in conversation: 7
#
# Conversation ID: L357049
# Metadata: ConvoKitMeta({'movie_idx': 'm124', 'movie_name': 'lost horizon', 'release_year': '1937', 'rating': '7.80', 'votes': '5509', 'genre': "['adventure', 'drama', 'fantasy', 'mystery']"})
# Number of utterances in conversation: 4
#
# Conversation ID: L357043
# Metadata: ConvoKitMeta({'movie_idx': 'm124', 'movie_name': 'lost horizon', 'release_year': '1937', 'rating': '7.80', 'votes': '5509', 'genre': "['adventure', 'drama', 'fantasy', 'mystery']"})
# Number of utterances in conversation: 4
#
# Conversation ID: L356939
# Metadata: ConvoKitMeta({'movie_idx': 'm124', 'movie_name': 'lost horizon', 'release_year': '1937', 'rating': '7.80', 'votes': '5509', 'genre': "['adventure', 'drama', 'fantasy', 'mystery']"})
# Number of utterances in conversation: 3
#
# Conversation ID: L356934
# Metadata: ConvoKitMeta({'movie_idx': 'm124', 'movie_name': 'lost horizon', 'release_year': '1937', 'rating': '7.80', 'votes': '5509', 'genre': "['adventure', 'drama', 'fantasy', 'mystery']"})
# ...
# Number of utterances in conversation: 6
#
# Conversation ID: L666019
# Metadata: ConvoKitMeta({'movie_idx': 'm615', 'movie_name': 'young frankenstein', 'release_year': '1974', 'rating': '8.00', 'votes': '57618', 'genre': "['comedy', 'sci-fi']"})
# Number of utterances in conversation: 4
#
# Conversation ID: L665957
# Metadata: ConvoKitMeta({'movie_idx': 'm615', 'movie_name': 'young frankenstein', 'release_year': '1974', 'rating': '8.00', 'votes': '57618', 'genre': "['comedy', 'sci-fi']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L665904
# Metadata: ConvoKitMeta({'movie_idx': 'm615', 'movie_name': 'young frankenstein', 'release_year': '1974', 'rating': '8.00', 'votes': '57618', 'genre': "['comedy', 'sci-fi']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L665896
# Metadata: ConvoKitMeta({'movie_idx': 'm615', 'movie_name': 'young frankenstein', 'release_year': '1974', 'rating': '8.00', 'votes': '57618', 'genre': "['comedy', 'sci-fi']"})
# Number of utterances in conversation: 3
#
# Conversation ID: L665891
# Metadata: ConvoKitMeta({'movie_idx': 'm615', 'movie_name': 'young frankenstein', 'release_year': '1974', 'rating': '8.00', 'votes': '57618', 'genre': "['comedy', 'sci-fi']"})
# Number of utterances in conversation: 4
#
# Conversation ID: L665873
# Metadata: ConvoKitMeta({'movie_idx': 'm615', 'movie_name': 'young frankenstein', 'release_year': '1974', 'rating': '8.00', 'votes': '57618', 'genre': "['comedy', 'sci-fi']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L665868
# Metadata: ConvoKitMeta({'movie_idx': 'm615', 'movie_name': 'young frankenstein', 'release_year': '1974', 'rating': '8.00', 'votes': '57618', 'genre': "['comedy', 'sci-fi']"})
# Number of utterances in conversation: 3
#
# Conversation ID: L665865
# Metadata: ConvoKitMeta({'movie_idx': 'm615', 'movie_name': 'young frankenstein', 'release_year': '1974', 'rating': '8.00', 'votes': '57618', 'genre': "['comedy', 'sci-fi']"})
# Number of utterances in conversation: 3
#
# Conversation ID: L665861
# Metadata: ConvoKitMeta({'movie_idx': 'm615', 'movie_name': 'young frankenstein', 'release_year': '1974', 'rating': '8.00', 'votes': '57618', 'genre': "['comedy', 'sci-fi']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L665840
# Metadata: ConvoKitMeta({'movie_idx': 'm615', 'movie_name': 'young frankenstein', 'release_year': '1974', 'rating': '8.00', 'votes': '57618', 'genre': "['comedy', 'sci-fi']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L665802
# Metadata: ConvoKitMeta({'movie_idx': 'm615', 'movie_name': 'young frankenstein', 'release_year': '1974', 'rating': '8.00', 'votes': '57618', 'genre': "['comedy', 'sci-fi']"})
# Number of utterances in conversation: 3
#
# Conversation ID: L665798
# Metadata: ConvoKitMeta({'movie_idx': 'm615', 'movie_name': 'young frankenstein', 'release_year': '1974', 'rating': '8.00', 'votes': '57618', 'genre': "['comedy', 'sci-fi']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L665775
# Metadata: ConvoKitMeta({'movie_idx': 'm615', 'movie_name': 'young frankenstein', 'release_year': '1974', 'rating': '8.00', 'votes': '57618', 'genre': "['comedy', 'sci-fi']"})
# Number of utterances in conversation: 3
#
# Conversation ID: L665755
# Metadata: ConvoKitMeta({'movie_idx': 'm615', 'movie_name': 'young frankenstein', 'release_year': '1974', 'rating': '8.00', 'votes': '57618', 'genre': "['comedy', 'sci-fi']"})
# Number of utterances in conversation: 3
#
# Conversation ID: L665748
# Metadata: ConvoKitMeta({'movie_idx': 'm615', 'movie_name': 'young frankenstein', 'release_year': '1974', 'rating': '8.00', 'votes': '57618', 'genre': "['comedy', 'sci-fi']"})
# Number of utterances in conversation: 5
#
# Conversation ID: L665691
# Metadata: ConvoKitMeta({'movie_idx': 'm615', 'movie_name': 'young frankenstein', 'release_year': '1974', 'rating': '8.00', 'votes': '57618', 'genre': "['comedy', 'sci-fi']"})
# Number of utterances in conversation: 3
#
# Conversation ID: L665676
# Metadata: ConvoKitMeta({'movie_idx': 'm615', 'movie_name': 'young frankenstein', 'release_year': '1974', 'rating': '8.00', 'votes': '57618', 'genre': "['comedy', 'sci-fi']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L665663
# Metadata: ConvoKitMeta({'movie_idx': 'm615', 'movie_name': 'young frankenstein', 'release_year': '1974', 'rating': '8.00', 'votes': '57618', 'genre': "['comedy', 'sci-fi']"})
# Number of utterances in conversation: 3
#
# Conversation ID: L665658
# Metadata: ConvoKitMeta({'movie_idx': 'm615', 'movie_name': 'young frankenstein', 'release_year': '1974', 'rating': '8.00', 'votes': '57618', 'genre': "['comedy', 'sci-fi']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L665636
# Metadata: ConvoKitMeta({'movie_idx': 'm615', 'movie_name': 'young frankenstein', 'release_year': '1974', 'rating': '8.00', 'votes': '57618', 'genre': "['comedy', 'sci-fi']"})
# Number of utterances in conversation: 4
#
# Conversation ID: L665627
# Metadata: ConvoKitMeta({'movie_idx': 'm615', 'movie_name': 'young frankenstein', 'release_year': '1974', 'rating': '8.00', 'votes': '57618', 'genre': "['comedy', 'sci-fi']"})
# Number of utterances in conversation: 7
#
# Conversation ID: L665623
# Metadata: ConvoKitMeta({'movie_idx': 'm615', 'movie_name': 'young frankenstein', 'release_year': '1974', 'rating': '8.00', 'votes': '57618', 'genre': "['comedy', 'sci-fi']"})
# Number of utterances in conversation: 3
#
# Conversation ID: L665615
# Metadata: ConvoKitMeta({'movie_idx': 'm615', 'movie_name': 'young frankenstein', 'release_year': '1974', 'rating': '8.00', 'votes': '57618', 'genre': "['comedy', 'sci-fi']"})
# Number of utterances in conversation: 8
#
# Conversation ID: L665564
# Metadata: ConvoKitMeta({'movie_idx': 'm615', 'movie_name': 'young frankenstein', 'release_year': '1974', 'rating': '8.00', 'votes': '57618', 'genre': "['comedy', 'sci-fi']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L665558
# Metadata: ConvoKitMeta({'movie_idx': 'm615', 'movie_name': 'young frankenstein', 'release_year': '1974', 'rating': '8.00', 'votes': '57618', 'genre': "['comedy', 'sci-fi']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L665552
# Metadata: ConvoKitMeta({'movie_idx': 'm615', 'movie_name': 'young frankenstein', 'release_year': '1974', 'rating': '8.00', 'votes': '57618', 'genre': "['comedy', 'sci-fi']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L665548
# Metadata: ConvoKitMeta({'movie_idx': 'm615', 'movie_name': 'young frankenstein', 'release_year': '1974', 'rating': '8.00', 'votes': '57618', 'genre': "['comedy', 'sci-fi']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L666168
# Metadata: ConvoKitMeta({'movie_idx': 'm615', 'movie_name': 'young frankenstein', 'release_year': '1974', 'rating': '8.00', 'votes': '57618', 'genre': "['comedy', 'sci-fi']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L666166
# Metadata: ConvoKitMeta({'movie_idx': 'm615', 'movie_name': 'young frankenstein', 'release_year': '1974', 'rating': '8.00', 'votes': '57618', 'genre': "['comedy', 'sci-fi']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L666160
# Metadata: ConvoKitMeta({'movie_idx': 'm615', 'movie_name': 'young frankenstein', 'release_year': '1974', 'rating': '8.00', 'votes': '57618', 'genre': "['comedy', 'sci-fi']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L666158
# Metadata: ConvoKitMeta({'movie_idx': 'm615', 'movie_name': 'young frankenstein', 'release_year': '1974', 'rating': '8.00', 'votes': '57618', 'genre': "['comedy', 'sci-fi']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L666151
# Metadata: ConvoKitMeta({'movie_idx': 'm615', 'movie_name': 'young frankenstein', 'release_year': '1974', 'rating': '8.00', 'votes': '57618', 'genre': "['comedy', 'sci-fi']"})
# Number of utterances in conversation: 6
#
# Conversation ID: L666149
# Metadata: ConvoKitMeta({'movie_idx': 'm615', 'movie_name': 'young frankenstein', 'release_year': '1974', 'rating': '8.00', 'votes': '57618', 'genre': "['comedy', 'sci-fi']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L665949
# Metadata: ConvoKitMeta({'movie_idx': 'm615', 'movie_name': 'young frankenstein', 'release_year': '1974', 'rating': '8.00', 'votes': '57618', 'genre': "['comedy', 'sci-fi']"})
# Number of utterances in conversation: 4
#
# Conversation ID: L665900
# Metadata: ConvoKitMeta({'movie_idx': 'm615', 'movie_name': 'young frankenstein', 'release_year': '1974', 'rating': '8.00', 'votes': '57618', 'genre': "['comedy', 'sci-fi']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L665885
# Metadata: ConvoKitMeta({'movie_idx': 'm615', 'movie_name': 'young frankenstein', 'release_year': '1974', 'rating': '8.00', 'votes': '57618', 'genre': "['comedy', 'sci-fi']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L665694
# Metadata: ConvoKitMeta({'movie_idx': 'm615', 'movie_name': 'young frankenstein', 'release_year': '1974', 'rating': '8.00', 'votes': '57618', 'genre': "['comedy', 'sci-fi']"})
# Number of utterances in conversation: 3
#
# Conversation ID: L665651
# Metadata: ConvoKitMeta({'movie_idx': 'm615', 'movie_name': 'young frankenstein', 'release_year': '1974', 'rating': '8.00', 'votes': '57618', 'genre': "['comedy', 'sci-fi']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L665994
# Metadata: ConvoKitMeta({'movie_idx': 'm615', 'movie_name': 'young frankenstein', 'release_year': '1974', 'rating': '8.00', 'votes': '57618', 'genre': "['comedy', 'sci-fi']"})
# Number of utterances in conversation: 4
#
# Conversation ID: L665992
# Metadata: ConvoKitMeta({'movie_idx': 'm615', 'movie_name': 'young frankenstein', 'release_year': '1974', 'rating': '8.00', 'votes': '57618', 'genre': "['comedy', 'sci-fi']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L665987
# Metadata: ConvoKitMeta({'movie_idx': 'm615', 'movie_name': 'young frankenstein', 'release_year': '1974', 'rating': '8.00', 'votes': '57618', 'genre': "['comedy', 'sci-fi']"})
# Number of utterances in conversation: 5
#
# Conversation ID: L666462
# Metadata: ConvoKitMeta({'movie_idx': 'm616', 'movie_name': 'zulu dawn', 'release_year': '1979', 'rating': '6.40', 'votes': '1911', 'genre': "['action', 'adventure', 'drama', 'history', 'war']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L666365
# Metadata: ConvoKitMeta({'movie_idx': 'm616', 'movie_name': 'zulu dawn', 'release_year': '1979', 'rating': '6.40', 'votes': '1911', 'genre': "['action', 'adventure', 'drama', 'history', 'war']"})
# Number of utterances in conversation: 4
#
# Conversation ID: L666361
# Metadata: ConvoKitMeta({'movie_idx': 'm616', 'movie_name': 'zulu dawn', 'release_year': '1979', 'rating': '6.40', 'votes': '1911', 'genre': "['action', 'adventure', 'drama', 'history', 'war']"})
# Number of utterances in conversation: 4
#
# Conversation ID: L666503
# Metadata: ConvoKitMeta({'movie_idx': 'm616', 'movie_name': 'zulu dawn', 'release_year': '1979', 'rating': '6.40', 'votes': '1911', 'genre': "['action', 'adventure', 'drama', 'history', 'war']"})
# Number of utterances in conversation: 3
#
# Conversation ID: L666388
# Metadata: ConvoKitMeta({'movie_idx': 'm616', 'movie_name': 'zulu dawn', 'release_year': '1979', 'rating': '6.40', 'votes': '1911', 'genre': "['action', 'adventure', 'drama', 'history', 'war']"})
# Number of utterances in conversation: 11
#
# Conversation ID: L666487
# Metadata: ConvoKitMeta({'movie_idx': 'm616', 'movie_name': 'zulu dawn', 'release_year': '1979', 'rating': '6.40', 'votes': '1911', 'genre': "['action', 'adventure', 'drama', 'history', 'war']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L666483
# Metadata: ConvoKitMeta({'movie_idx': 'm616', 'movie_name': 'zulu dawn', 'release_year': '1979', 'rating': '6.40', 'votes': '1911', 'genre': "['action', 'adventure', 'drama', 'history', 'war']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L666480
# Metadata: ConvoKitMeta({'movie_idx': 'm616', 'movie_name': 'zulu dawn', 'release_year': '1979', 'rating': '6.40', 'votes': '1911', 'genre': "['action', 'adventure', 'drama', 'history', 'war']"})
# Number of utterances in conversation: 3
#
# Conversation ID: L666357
# Metadata: ConvoKitMeta({'movie_idx': 'm616', 'movie_name': 'zulu dawn', 'release_year': '1979', 'rating': '6.40', 'votes': '1911', 'genre': "['action', 'adventure', 'drama', 'history', 'war']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L666249
# Metadata: ConvoKitMeta({'movie_idx': 'm616', 'movie_name': 'zulu dawn', 'release_year': '1979', 'rating': '6.40', 'votes': '1911', 'genre': "['action', 'adventure', 'drama', 'history', 'war']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L666246
# Metadata: ConvoKitMeta({'movie_idx': 'm616', 'movie_name': 'zulu dawn', 'release_year': '1979', 'rating': '6.40', 'votes': '1911', 'genre': "['action', 'adventure', 'drama', 'history', 'war']"})
# Number of utterances in conversation: 3
#
# Conversation ID: L666546
# Metadata: ConvoKitMeta({'movie_idx': 'm616', 'movie_name': 'zulu dawn', 'release_year': '1979', 'rating': '6.40', 'votes': '1911', 'genre': "['action', 'adventure', 'drama', 'history', 'war']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L666485
# Metadata: ConvoKitMeta({'movie_idx': 'm616', 'movie_name': 'zulu dawn', 'release_year': '1979', 'rating': '6.40', 'votes': '1911', 'genre': "['action', 'adventure', 'drama', 'history', 'war']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L666460
# Metadata: ConvoKitMeta({'movie_idx': 'm616', 'movie_name': 'zulu dawn', 'release_year': '1979', 'rating': '6.40', 'votes': '1911', 'genre': "['action', 'adventure', 'drama', 'history', 'war']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L666383
# Metadata: ConvoKitMeta({'movie_idx': 'm616', 'movie_name': 'zulu dawn', 'release_year': '1979', 'rating': '6.40', 'votes': '1911', 'genre': "['action', 'adventure', 'drama', 'history', 'war']"})
# Number of utterances in conversation: 3
#
# Conversation ID: L666251
# Metadata: ConvoKitMeta({'movie_idx': 'm616', 'movie_name': 'zulu dawn', 'release_year': '1979', 'rating': '6.40', 'votes': '1911', 'genre': "['action', 'adventure', 'drama', 'history', 'war']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L666497
# Metadata: ConvoKitMeta({'movie_idx': 'm616', 'movie_name': 'zulu dawn', 'release_year': '1979', 'rating': '6.40', 'votes': '1911', 'genre': "['action', 'adventure', 'drama', 'history', 'war']"})
# Number of utterances in conversation: 6
#
# Conversation ID: L666575
# Metadata: ConvoKitMeta({'movie_idx': 'm616', 'movie_name': 'zulu dawn', 'release_year': '1979', 'rating': '6.40', 'votes': '1911', 'genre': "['action', 'adventure', 'drama', 'history', 'war']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L666324
# Metadata: ConvoKitMeta({'movie_idx': 'm616', 'movie_name': 'zulu dawn', 'release_year': '1979', 'rating': '6.40', 'votes': '1911', 'genre': "['action', 'adventure', 'drama', 'history', 'war']"})
# Number of utterances in conversation: 4
#
# Conversation ID: L666262
# Metadata: ConvoKitMeta({'movie_idx': 'm616', 'movie_name': 'zulu dawn', 'release_year': '1979', 'rating': '6.40', 'votes': '1911', 'genre': "['action', 'adventure', 'drama', 'history', 'war']"})
# Number of utterances in conversation: 3
#
# Conversation ID: L666520
# Metadata: ConvoKitMeta({'movie_idx': 'm616', 'movie_name': 'zulu dawn', 'release_year': '1979', 'rating': '6.40', 'votes': '1911', 'genre': "['action', 'adventure', 'drama', 'history', 'war']"})
# Number of utterances in conversation: 3
#
# Conversation ID: L666369
# Metadata: ConvoKitMeta({'movie_idx': 'm616', 'movie_name': 'zulu dawn', 'release_year': '1979', 'rating': '6.40', 'votes': '1911', 'genre': "['action', 'adventure', 'drama', 'history', 'war']"})
# Number of utterances in conversation: 4
#
# Conversation ID: L666256
# Metadata: ConvoKitMeta({'movie_idx': 'm616', 'movie_name': 'zulu dawn', 'release_year': '1979', 'rating': '6.40', 'votes': '1911', 'genre': "['action', 'adventure', 'drama', 'history', 'war']"})
# Number of utterances in conversation: 2

# %%
import pandas as pd

# Extracting conversation metadata
data = [
    {
        'Conversation ID': convo.get_id(),
        'Movie Index': convo.meta['movie_idx'],
        'Movie Name': convo.meta['movie_name'],
        'Release Year': convo.meta['release_year'],
        'Rating': convo.meta['rating'],
        'Votes': convo.meta['votes'],
        'Genres': convo.meta['genre'],
        'Number of Utterances': len(convo.get_utterance_ids())
    }
    for convo in corpus.iter_conversations()
]

# Creating a DataFrame from the extracted data
df = pd.DataFrame(data)

# %%
#The DataFrame
print(df)
# Out:
#       Conversation ID Movie Index                  Movie Name Release Year  \
# 0               L1044          m0  10 things i hate about you         1999
# 1                L984          m0  10 things i hate about you         1999
# 2                L924          m0  10 things i hate about you         1999
# 3                L870          m0  10 things i hate about you         1999
# 4                L866          m0  10 things i hate about you         1999
# ...               ...         ...                         ...          ...
# 83092         L666324        m616                   zulu dawn         1979
# 83093         L666262        m616                   zulu dawn         1979
# 83094         L666520        m616                   zulu dawn         1979
# 83095         L666369        m616                   zulu dawn         1979
# 83096         L666256        m616                   zulu dawn         1979
#
#       Rating  Votes                                             Genres  \
# 0       6.90  62847                              ['comedy', 'romance']
# 1       6.90  62847                              ['comedy', 'romance']
# 2       6.90  62847                              ['comedy', 'romance']
# 3       6.90  62847                              ['comedy', 'romance']
# 4       6.90  62847                              ['comedy', 'romance']
# ...      ...    ...                                                ...
# 83092   6.40   1911  ['action', 'adventure', 'drama', 'history', 'w...
# 83093   6.40   1911  ['action', 'adventure', 'drama', 'history', 'w...
# 83094   6.40   1911  ['action', 'adventure', 'drama', 'history', 'w...
# 83095   6.40   1911  ['action', 'adventure', 'drama', 'history', 'w...
# 83096   6.40   1911  ['action', 'adventure', 'drama', 'history', 'w...
#
#        Number of Utterances
# 0                         2
# 1                         2
# 2                         2
# 3                         3
# 4                         4
# ...                     ...
# 83092                     4
# 83093                     3
# 83094                     3
# 83095                     4
# 83096                     2
#
# [83097 rows x 8 columns]

# %%
# Creating a Surprise Reader object to specify the rating scale
reader = Reader(rating_scale=(1, 10))

# %%
data = Dataset.load_from_df(df[['Conversation ID', 'Movie Name', 'Rating']], reader)

# %%
# Spliting the dataset into training and testing sets
trainset, testset = train_test_split(data, test_size=0.3, random_state=42)

# %%
# Initializing model
model=SVD()

# %%
model.fit(trainset)

# %%
predictions=model.test(testset)

# %%
rmse=accuracy.rmse(predictions)
print(f'RMSE:{rmse:.2f}')
# Out:
# RMSE: 0.0701
# RMSE:0.07

# %% [markdown]
#     An RMSE of 0.07 indicates that, on average, the model's predicted ratings are quite close to the actual ratings.

# %%
# Defining a function to get movie recommendations based on the SVD model
def get_movie_recommendations(movie_name, num_recommendations=10):
    all_movie_names = df['Movie Name'].unique()

    movie_ratings = [
        (other_movie, model.predict(movie_name, other_movie).est)
        for other_movie in all_movie_names
        if other_movie != movie_name
    ]

    movie_ratings.sort(key=lambda x: x[1], reverse=True)

    top_recommendations = movie_ratings[:num_recommendations]

    return top_recommendations

# %%
#Getting movie recommendations for a movie
movie_to_recommend = 'xxx'
recommendations = get_movie_recommendations(movie_to_recommend)
print(f"Top 10 movie recommendations for '{movie_to_recommend}':")
for idx, (other_movie, rating) in enumerate(recommendations, start=1):
    print(f"{idx}. Movie Name: '{other_movie}', Estimated Rating: {rating:.2f}")
# Out:
# Top 10 movie recommendations for 'xxx':
# 1. Movie Name: 'neuromancer', Estimated Rating: 9.16
# 2. Movie Name: 'the godfather', Estimated Rating: 9.11
# 3. Movie Name: 'the godfather: part ii', Estimated Rating: 8.91
# 4. Movie Name: 'one flew over the cuckoo's nest', Estimated Rating: 8.83
# 5. Movie Name: 'fight club', Estimated Rating: 8.73
# 6. Movie Name: 'schindler's list', Estimated Rating: 8.73
# 7. Movie Name: 'casablanca', Estimated Rating: 8.72
# 8. Movie Name: 'star wars', Estimated Rating: 8.72
# 9. Movie Name: 'goodfellas', Estimated Rating: 8.66
# 10. Movie Name: 'rear window', Estimated Rating: 8.64

# %%
#Recommendation for a User
def get_movie_recommendations_for_user(user_id, num_recommendations=3):
    user_conversations = df[df['Conversation ID'].str.contains(user_id, case=False, na=False)]
    movies_interacted = user_conversations['Movie Name'].unique()
    movies_not_interacted = df[~df['Movie Name'].isin(movies_interacted)]['Movie Name'].unique()
    movie_ratings = [
        (movie_name, model.predict(user_id, movie_name).est)
        for movie_name in movies_not_interacted
    ]

    movie_ratings.sort(key=lambda x: x[1], reverse=True)
    top_recommendations = movie_ratings[:num_recommendations]

    return top_recommendations

# %%
#Getting movie recommendations for a user with user_id
user_id_to_recommend = 'L666256'
recommendations = get_movie_recommendations_for_user(user_id_to_recommend)
print(f"Top 3 movie recommendations for user '{user_id_to_recommend}':")
for idx, (movie_name, rating) in enumerate(recommendations, start=1):
    print(f"{idx}. Movie Name: '{movie_name}', Estimated Rating: {rating:.2f}")
# Out:
# Top 3 movie recommendations for user 'L666256':
# 1. Movie Name: 'neuromancer', Estimated Rating: 9.16
# 2. Movie Name: 'the godfather', Estimated Rating: 9.11
# 3. Movie Name: 'the godfather: part ii', Estimated Rating: 8.91
